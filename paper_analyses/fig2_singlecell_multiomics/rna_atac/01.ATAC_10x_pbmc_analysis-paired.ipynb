# %% [markdown]
# # Paired multi-model analysis

# %% [markdown]
# Here we will use 10X PBMCs scRNA-seq dataset from scanpy as an example to illustrate how Garfield performs scRNA-seq clustering analysis

# %%
import os
os.chdir('/data2/zhouwg_data/project/Garfield')
os.getcwd()
# Out:
# '/data2/zhouwg_data/project/Garfield'

# %%
# load packages
import os
import warnings
import Garfield as gf
import scanpy as sc
from mudata import MuData
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

gf.__version__
# Out:
# '0.3.6'

# %%
## load data
rna = sc.read_h5ad('/home/zhouweige/zhouwg_data/project/Garfield_tutorials/data/human_pbmc_10x_3k_RNA.h5ad')
rna.layers['counts'] = rna.X.copy()
rna.obs['batch'] = 'RNA'
atac = sc.read_h5ad('/home/zhouweige/zhouwg_data/project/Garfield_tutorials/data/human_pbmc_10x_3k_ATAC.h5ad')
atac.layers['counts'] = atac.X.copy()
atac.obs['batch'] = 'ATAC'

# split each element for gene score calculation
split_data = atac.var_names.str.split('-', expand=True).to_frame(index=False)
split_data.index = atac.var_names
split_data.columns = ['chr', 'start', 'end']
atac.var[['chr', 'start', 'end']] = split_data

mdata = MuData({"rna": rna, "atac": atac})
mdata
# Out:
# MuData object with n_obs × n_vars = 2590 × 134920
#   var:	'gene'
#   2 modalities
#     rna:	2590 x 36601
#       obs:	'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'nCount_peaks', 'nFeature_peaks', 'RNA_snn_res.1', 'seurat_clusters', 'celltype', 'RNA.weight', 'peaks.weight', 'batch'
#       var:	'gene'
#       layers:	'counts'
#     atac:	2590 x 98319
#       obs:	'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'nCount_peaks', 'nFeature_peaks', 'RNA_snn_res.1', 'seurat_clusters', 'celltype', 'RNA.weight', 'peaks.weight', 'batch'
#       var:	'gene', 'chr', 'start', 'end'
#       layers:	'counts'

# %%
# process all RNA features
rna_adata = rna.copy()
sc.pp.normalize_total(rna_adata)
sc.pp.log1p(rna_adata)
sc.pp.highly_variable_genes(rna_adata)
# only retain highly variable genes
rna_adata = rna_adata[:, rna_adata.var.highly_variable].copy()
sc.pp.scale(rna_adata)

# plot UMAPs of rna cells based on all active rna markers
sc.pp.neighbors(rna_adata, n_neighbors=15)
sc.tl.umap(rna_adata)
sc.pl.umap(rna_adata, color=['celltype'], wspace=0.15, show=True, size=3, legend_loc='on data')
# Out:
# WARNING: You’re trying to run this on 3914 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.pl.umap(rna_adata, color=['celltype'], wspace=0.15, show=True, size=3, legend_loc='on data')

# %%
# process all RNA features
rna_adata = atac.copy()
sc.pp.normalize_total(rna_adata)
sc.pp.log1p(rna_adata)
sc.pp.highly_variable_genes(rna_adata)
# only retain highly variable genes
rna_adata = rna_adata[:, rna_adata.var.highly_variable].copy()
sc.pp.scale(rna_adata)

# plot UMAPs of rna cells based on all active rna markers
sc.pp.neighbors(rna_adata, n_neighbors=15)
sc.tl.umap(rna_adata)
sc.pl.umap(rna_adata, color=['celltype'], wspace=0.15, show=True, size=3, legend_loc='on data')
# Out:
# WARNING: You’re trying to run this on 23645 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %% [markdown]
# ## Perform single-cell multi-omics integration using Garfield

# %% [markdown]
# For integration of multi-omics single-cell data, we should adjust the following paremeters,
# and all parameter introductions can be found in [Garfield_Model_Parameters](https://github.com/zhou-1314/Garfield/blob/main/Garfield_Model_Parameters.md).

# %%
# set workdir
workdir = '/home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_multiome_10xpbmc3k'
gf.settings.set_workdir(workdir)

### modify parameter
user_config = dict(
    ## Input options
    adata_list=mdata, 
    profile='multi-modal',   # if it is 'ATAC' or 'ADT', please adjust it.
    data_type='Paired',
    sub_data_type=['rna', 'atac'],
    sample_col=None,  # Specify columns for batch, only one batch, so set `None`
    weight=0.8,

    ## Preprocessing options
    genome='hg38',
    use_gene_weight=True,
    use_top_pcs=False,
    used_hvg=True,
    min_cells=3,
    min_features=0,
    keep_mt=False,
    target_sum=1e4,
    rna_n_top_features=3000,
    atac_n_top_features=10000, # if data belongs to 'ATAC', please specify it.
    n_components=50,
    n_neighbors=5,
    metric='euclidean',  
    svd_solver='arpack',
    # datasets
    used_pca_feat=True,
    adj_key='connectivities',
    
    # data split parameters
    edge_val_ratio=0.1,
    edge_test_ratio=0.,
    node_val_ratio=0.1,
    node_test_ratio=0.,

    ## Model options
    augment_type='svd',
    svd_q=5,
    use_FCencoder=False, 
    conv_type='GATv2Conv', # GAT or GATv2Conv or GCN
    gnn_layer=2,
    hidden_dims=[128, 128],
    bottle_neck_neurons=20,
    cluster_num=20,
    drop_feature_rate=0.2, 
    drop_edge_rate=0.2,
    num_heads=3,
    dropout=0.2,
    concat=True,
    used_edge_weight=True,
    used_DSBN=False,
    used_mmd=False,
    # data loader parameters
    num_neighbors=5,
    loaders_n_hops=2,
    edge_batch_size=4096,
    node_batch_size=128, # None
    # loss parameters
    include_edge_recon_loss=True,
    include_gene_expr_recon_loss=True,
    lambda_latent_contrastive_instanceloss=1.0,
    lambda_latent_contrastive_clusterloss=0.5,
    lambda_gene_expr_recon=1., # To make the model more focused on learning expression features, increase this parameter.
    lambda_edge_recon=5., # To make the model more focused on learning Adjacency graph features, increase this parameter.
    lambda_latent_adj_recon_loss=1.0,
    lambda_omics_recon_mmd_loss=3., # If the integration is not strong enough, increase it.
    # train parameters
    n_epochs_no_edge_recon=0,
    learning_rate=0.001,
    weight_decay=1e-05,
    gradient_clipping=5,
    # other parameters
    latent_key='garfield_latent',
    reload_best_model=True,
    use_early_stopping=True,
    early_stopping_kwargs=None,
    monitor=True,
    device_id=1,
    seed=2024,
    verbose=True
)
dict_config = gf.settings.set_gf_params(user_config)
# Out:
# Saving results in: /home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_multiome_10xpbmc3k

# %%
from Garfield.model import Garfield

# Initialize model
model = Garfield(dict_config)
# Out:
# --- DATA LOADING AND PREPROCESSING ---
# Gene activity matrix has been calculated, and loading cached adata_CG_atac object...
# There are 16299 common genes in RNA and ATAC datasets
# To start performing cell matching for adjacency matrix of the graph, please wait...
# Init_matching done!
# Refined_matching done!
# Filter_bad_matches on pivots matching...
# Begin filtering...
# 1813/2590 pairs of matched cells remain after the filtering.
# Fitting CCA on pivots...
# Scoring matched pairs...
# Done!
# Filter_bad_matches on propagated matching...
# Begin filtering...
# 1554/1554 pairs of matched cells remain after the filtering.
# Fitting CCA on pivots...
# Scoring matched pairs...
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.2

# %%
# Train model
model.train()
# Out:
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2331
# Number of validation nodes: 259
# Number of training edges: 17189
# Number of validation edges: 1909
# Edge batch size: 4096
# Node batch size: 128
#
# --- MODEL TRAINING ---
# Epoch 1/100 |--------------------| 1.0% val_auroc_score: 0.8927; val_auprc_score: 0.8671; val_best_acc_score: 0.8177; val_best_f1_score: 0.8351; train_kl_reg_loss: 74521440.7234; train_edge_recon_loss: 4765.6776; train_gene_expr_recon_loss: 4294800058.4625; train_lambda_latent_adj_recon_loss: 1358.5493; train_lambda_latent_contrastive_instanceloss: 7.1073; train_lambda_latent_contrastive_clusterloss: 3.7445; train_global_loss: 4369327644.4000; train_optim_loss: 4369327644.4000; val_kl_reg_loss: 439.0629; val_edge_recon_loss: 2787.5571; val_gene_expr_recon_loss: 231546.2812; val_lambda_latent_adj_recon_loss: 1479.5103; val_lambda_latent_contrastive_instanceloss: 6.9763; val_lambda_latent_contrastive_clusterloss: 3.7050; val_global_loss: 236263.0938; val_optim_loss: 236263.0938
# Epoch 2/100 |--------------------| 2.0% val_auroc_score: 0.8818; val_auprc_score: 0.8465; val_best_acc_score: 0.8085; val_best_f1_score: 0.8218; train_kl_reg_loss: 50576.4434; train_edge_recon_loss: 4805.9446; train_gene_expr_recon_loss: 329871.5625; train_lambda_latent_adj_recon_loss: 1833.3871; train_lambda_latent_contrastive_instanceloss: 7.0914; train_lambda_latent_contrastive_clusterloss: 3.7260; train_global_loss: 387098.1562; train_optim_loss: 387098.1562; val_kl_reg_loss: 70.3294; val_edge_recon_loss: 2805.6753; val_gene_expr_recon_loss: 242705.7656; val_lambda_latent_adj_recon_loss: 1903.3027; val_lambda_latent_contrastive_instanceloss: 6.8966; val_lambda_latent_contrastive_clusterloss: 3.7365; val_global_loss: 247495.6875; val_optim_loss: 247495.6875
# Epoch 3/100 |--------------------| 3.0% val_auroc_score: 0.8826; val_auprc_score: 0.8387; val_best_acc_score: 0.8384; val_best_f1_score: 0.8532; train_kl_reg_loss: 193.6154; train_edge_recon_loss: 4753.3387; train_gene_expr_recon_loss: 404053.3688; train_lambda_latent_adj_recon_loss: 1887.5790; train_lambda_latent_contrastive_instanceloss: 7.0388; train_lambda_latent_contrastive_clusterloss: 3.7116; train_global_loss: 410898.6531; train_optim_loss: 410898.6531; val_kl_reg_loss: 188.6313; val_edge_recon_loss: 2508.5925; val_gene_expr_recon_loss: 213263.9062; val_lambda_latent_adj_recon_loss: 1382.0032; val_lambda_latent_contrastive_instanceloss: 6.6841; val_lambda_latent_contrastive_clusterloss: 3.6629; val_global_loss: 217353.4688; val_optim_loss: 217353.4688
# Epoch 4/100 |--------------------| 4.0% val_auroc_score: 0.9008; val_auprc_score: 0.8627; val_best_acc_score: 0.8491; val_best_f1_score: 0.8613; train_kl_reg_loss: 4505474.0759; train_edge_recon_loss: 4654.4918; train_gene_expr_recon_loss: 84975833.4844; train_lambda_latent_adj_recon_loss: 1984.8714; train_lambda_latent_contrastive_instanceloss: 6.9455; train_lambda_latent_contrastive_clusterloss: 3.6648; train_global_loss: 89487953.9688; train_optim_loss: 89487953.9688; val_kl_reg_loss: 194.3209; val_edge_recon_loss: 2367.6445; val_gene_expr_recon_loss: 172937.8750; val_lambda_latent_adj_recon_loss: 1409.6682; val_lambda_latent_contrastive_instanceloss: 6.6434; val_lambda_latent_contrastive_clusterloss: 3.6260; val_global_loss: 176919.7812; val_optim_loss: 176919.7812
# Epoch 5/100 |█-------------------| 5.0% val_auroc_score: 0.8855; val_auprc_score: 0.8344; val_best_acc_score: 0.8384; val_best_f1_score: 0.8553; train_kl_reg_loss: 1405.1898; train_edge_recon_loss: 4598.0429; train_gene_expr_recon_loss: 213708.0875; train_lambda_latent_adj_recon_loss: 2048.4678; train_lambda_latent_contrastive_instanceloss: 6.8461; train_lambda_latent_contrastive_clusterloss: 3.6315; train_global_loss: 221770.2563; train_optim_loss: 221770.2563; val_kl_reg_loss: 200.7129; val_edge_recon_loss: 2376.2024; val_gene_expr_recon_loss: 177138.4688; val_lambda_latent_adj_recon_loss: 1731.5300; val_lambda_latent_contrastive_instanceloss: 6.6008; val_lambda_latent_contrastive_clusterloss: 3.5725; val_global_loss: 181457.0938; val_optim_loss: 181457.0938
# Epoch 6/100 |█-------------------| 6.0% val_auroc_score: 0.8913; val_auprc_score: 0.8459; val_best_acc_score: 0.8379; val_best_f1_score: 0.8535; train_kl_reg_loss: 426.5709; train_edge_recon_loss: 4533.6731; train_gene_expr_recon_loss: 213358.2719; train_lambda_latent_adj_recon_loss: 2015.0655; train_lambda_latent_contrastive_instanceloss: 6.8077; train_lambda_latent_contrastive_clusterloss: 3.6041; train_global_loss: 220343.9937; train_optim_loss: 220343.9937; val_kl_reg_loss: 244.0860; val_edge_recon_loss: 2398.9556; val_gene_expr_recon_loss: 193370.7188; val_lambda_latent_adj_recon_loss: 2156.3140; val_lambda_latent_contrastive_instanceloss: 6.5913; val_lambda_latent_contrastive_clusterloss: 3.5473; val_global_loss: 198180.2188; val_optim_loss: 198180.2188
# Epoch 7/100 |█-------------------| 7.0% val_auroc_score: 0.9007; val_auprc_score: 0.8631; val_best_acc_score: 0.8418; val_best_f1_score: 0.8556; train_kl_reg_loss: 505.1305; train_edge_recon_loss: 4522.2701; train_gene_expr_recon_loss: 170217.4875; train_lambda_latent_adj_recon_loss: 2069.0537; train_lambda_latent_contrastive_instanceloss: 6.7560; train_lambda_latent_contrastive_clusterloss: 3.5785; train_global_loss: 177324.2719; train_optim_loss: 177324.2719; val_kl_reg_loss: 221.4225; val_edge_recon_loss: 2423.2522; val_gene_expr_recon_loss: 144664.8438; val_lambda_latent_adj_recon_loss: 2233.0212; val_lambda_latent_contrastive_instanceloss: 6.6079; val_lambda_latent_contrastive_clusterloss: 3.5151; val_global_loss: 149552.6562; val_optim_loss: 149552.6562
# Epoch 8/100 |█-------------------| 8.0% val_auroc_score: 0.9042; val_auprc_score: 0.8630; val_best_acc_score: 0.8476; val_best_f1_score: 0.8587; train_kl_reg_loss: 2950.4013; train_edge_recon_loss: 4502.1365; train_gene_expr_recon_loss: 684878.8875; train_lambda_latent_adj_recon_loss: 2148.1634; train_lambda_latent_contrastive_instanceloss: 6.7376; train_lambda_latent_contrastive_clusterloss: 3.5459; train_global_loss: 694489.8562; train_optim_loss: 694489.8562; val_kl_reg_loss: 272.1041; val_edge_recon_loss: 2389.7402; val_gene_expr_recon_loss: 157035.7344; val_lambda_latent_adj_recon_loss: 2279.0708; val_lambda_latent_contrastive_instanceloss: 6.6230; val_lambda_latent_contrastive_clusterloss: 3.4796; val_global_loss: 161986.7656; val_optim_loss: 161986.7656
# Epoch 9/100 |█-------------------| 9.0% val_auroc_score: 0.9120; val_auprc_score: 0.8808; val_best_acc_score: 0.8502; val_best_f1_score: 0.8620; train_kl_reg_loss: 401.7099; train_edge_recon_loss: 4508.3296; train_gene_expr_recon_loss: 159689.8281; train_lambda_latent_adj_recon_loss: 2229.5667; train_lambda_latent_contrastive_instanceloss: 6.7079; train_lambda_latent_contrastive_clusterloss: 3.5172; train_global_loss: 166839.6547; train_optim_loss: 166839.6547; val_kl_reg_loss: 279.5937; val_edge_recon_loss: 2433.1582; val_gene_expr_recon_loss: 152098.9375; val_lambda_latent_adj_recon_loss: 2340.7896; val_lambda_latent_contrastive_instanceloss: 6.5635; val_lambda_latent_contrastive_clusterloss: 3.4567; val_global_loss: 157162.5000; val_optim_loss: 157162.5000
# Epoch 10/100 |██------------------| 10.0% val_auroc_score: 0.9231; val_auprc_score: 0.8943; val_best_acc_score: 0.8604; val_best_f1_score: 0.8726; train_kl_reg_loss: 416.8512; train_edge_recon_loss: 4503.6151; train_gene_expr_recon_loss: 152655.9781; train_lambda_latent_adj_recon_loss: 2244.1109; train_lambda_latent_contrastive_instanceloss: 6.6237; train_lambda_latent_contrastive_clusterloss: 3.4735; train_global_loss: 159830.6562; train_optim_loss: 159830.6562; val_kl_reg_loss: 287.5099; val_edge_recon_loss: 2419.3064; val_gene_expr_recon_loss: 147424.4844; val_lambda_latent_adj_recon_loss: 2509.1082; val_lambda_latent_contrastive_instanceloss: 6.5456; val_lambda_latent_contrastive_clusterloss: 3.4056; val_global_loss: 152650.3594; val_optim_loss: 152650.3594
# Epoch 11/100 |██------------------| 11.0% val_auroc_score: 0.9250; val_auprc_score: 0.9038; val_best_acc_score: 0.8596; val_best_f1_score: 0.8725; train_kl_reg_loss: 447.8585; train_edge_recon_loss: 4501.9457; train_gene_expr_recon_loss: 134454.9516; train_lambda_latent_adj_recon_loss: 2303.4103; train_lambda_latent_contrastive_instanceloss: 6.6042; train_lambda_latent_contrastive_clusterloss: 3.4382; train_global_loss: 141718.2078; train_optim_loss: 141718.2078; val_kl_reg_loss: 284.4192; val_edge_recon_loss: 2444.8376; val_gene_expr_recon_loss: 150254.5000; val_lambda_latent_adj_recon_loss: 2512.9695; val_lambda_latent_contrastive_instanceloss: 6.5431; val_lambda_latent_contrastive_clusterloss: 3.3929; val_global_loss: 155506.6562; val_optim_loss: 155506.6562
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 0.0001.
#
# Epoch 12/100 |██------------------| 12.0% val_auroc_score: 0.9323; val_auprc_score: 0.9129; val_best_acc_score: 0.8690; val_best_f1_score: 0.8792; train_kl_reg_loss: 338.9740; train_edge_recon_loss: 4473.6290; train_gene_expr_recon_loss: 126904.6531; train_lambda_latent_adj_recon_loss: 2354.9992; train_lambda_latent_contrastive_instanceloss: 6.5881; train_lambda_latent_contrastive_clusterloss: 3.4208; train_global_loss: 134082.2641; train_optim_loss: 134082.2641; val_kl_reg_loss: 281.3526; val_edge_recon_loss: 2419.4915; val_gene_expr_recon_loss: 158056.9219; val_lambda_latent_adj_recon_loss: 2534.7756; val_lambda_latent_contrastive_instanceloss: 6.5445; val_lambda_latent_contrastive_clusterloss: 3.3801; val_global_loss: 163302.4688; val_optim_loss: 163302.4688
# Epoch 13/100 |██------------------| 13.0% val_auroc_score: 0.9315; val_auprc_score: 0.9050; val_best_acc_score: 0.8693; val_best_f1_score: 0.8787; train_kl_reg_loss: 341.3105; train_edge_recon_loss: 4476.6856; train_gene_expr_recon_loss: 133158.7859; train_lambda_latent_adj_recon_loss: 2338.6854; train_lambda_latent_contrastive_instanceloss: 6.6665; train_lambda_latent_contrastive_clusterloss: 3.4487; train_global_loss: 140325.5797; train_optim_loss: 140325.5797; val_kl_reg_loss: 283.2815; val_edge_recon_loss: 2410.4500; val_gene_expr_recon_loss: 125163.1328; val_lambda_latent_adj_recon_loss: 2425.3181; val_lambda_latent_contrastive_instanceloss: 6.4874; val_lambda_latent_contrastive_clusterloss: 3.3647; val_global_loss: 130292.0391; val_optim_loss: 130292.0391
# Epoch 14/100 |██------------------| 14.0% val_auroc_score: 0.9308; val_auprc_score: 0.9070; val_best_acc_score: 0.8680; val_best_f1_score: 0.8764; train_kl_reg_loss: 360.6805; train_edge_recon_loss: 4465.0660; train_gene_expr_recon_loss: 169892.6562; train_lambda_latent_adj_recon_loss: 2405.6460; train_lambda_latent_contrastive_instanceloss: 6.5684; train_lambda_latent_contrastive_clusterloss: 3.4073; train_global_loss: 177134.0281; train_optim_loss: 177134.0281; val_kl_reg_loss: 293.0768; val_edge_recon_loss: 2407.5146; val_gene_expr_recon_loss: 142306.5156; val_lambda_latent_adj_recon_loss: 2503.4197; val_lambda_latent_contrastive_instanceloss: 6.5166; val_lambda_latent_contrastive_clusterloss: 3.3715; val_global_loss: 147520.4219; val_optim_loss: 147520.4219
# Epoch 15/100 |███-----------------| 15.0% val_auroc_score: 0.9286; val_auprc_score: 0.9024; val_best_acc_score: 0.8667; val_best_f1_score: 0.8772; train_kl_reg_loss: 353.3921; train_edge_recon_loss: 4469.7604; train_gene_expr_recon_loss: 137710.8422; train_lambda_latent_adj_recon_loss: 2343.6499; train_lambda_latent_contrastive_instanceloss: 6.5676; train_lambda_latent_contrastive_clusterloss: 3.4103; train_global_loss: 144887.6187; train_optim_loss: 144887.6187; val_kl_reg_loss: 277.7181; val_edge_recon_loss: 2423.1838; val_gene_expr_recon_loss: 123518.6953; val_lambda_latent_adj_recon_loss: 2422.6814; val_lambda_latent_contrastive_instanceloss: 6.5401; val_lambda_latent_contrastive_clusterloss: 3.3639; val_global_loss: 128652.1797; val_optim_loss: 128652.1797
# Epoch 16/100 |███-----------------| 16.0% val_auroc_score: 0.9331; val_auprc_score: 0.9077; val_best_acc_score: 0.8732; val_best_f1_score: 0.8809; train_kl_reg_loss: 348.7096; train_edge_recon_loss: 4456.4426; train_gene_expr_recon_loss: 130680.8766; train_lambda_latent_adj_recon_loss: 2299.9984; train_lambda_latent_contrastive_instanceloss: 6.5686; train_lambda_latent_contrastive_clusterloss: 3.3973; train_global_loss: 137795.9922; train_optim_loss: 137795.9922; val_kl_reg_loss: 294.9857; val_edge_recon_loss: 2397.1414; val_gene_expr_recon_loss: 144452.0625; val_lambda_latent_adj_recon_loss: 2528.9204; val_lambda_latent_contrastive_instanceloss: 6.4889; val_lambda_latent_contrastive_clusterloss: 3.3623; val_global_loss: 149682.9531; val_optim_loss: 149682.9531
# Epoch 17/100 |███-----------------| 17.0% val_auroc_score: 0.9271; val_auprc_score: 0.8975; val_best_acc_score: 0.8693; val_best_f1_score: 0.8783; train_kl_reg_loss: 344.2807; train_edge_recon_loss: 4460.8220; train_gene_expr_recon_loss: 141418.4937; train_lambda_latent_adj_recon_loss: 2333.9503; train_lambda_latent_contrastive_instanceloss: 6.5758; train_lambda_latent_contrastive_clusterloss: 3.3993; train_global_loss: 148567.5172; train_optim_loss: 148567.5172; val_kl_reg_loss: 284.3372; val_edge_recon_loss: 2421.8413; val_gene_expr_recon_loss: 137984.9688; val_lambda_latent_adj_recon_loss: 2531.1218; val_lambda_latent_contrastive_instanceloss: 6.5074; val_lambda_latent_contrastive_clusterloss: 3.3538; val_global_loss: 143232.1250; val_optim_loss: 143232.1250
# Epoch 18/100 |███-----------------| 18.0% val_auroc_score: 0.9248; val_auprc_score: 0.8943; val_best_acc_score: 0.8617; val_best_f1_score: 0.8732; train_kl_reg_loss: 339.7641; train_edge_recon_loss: 4450.1469; train_gene_expr_recon_loss: 134296.6562; train_lambda_latent_adj_recon_loss: 2337.3666; train_lambda_latent_contrastive_instanceloss: 6.6695; train_lambda_latent_contrastive_clusterloss: 3.4333; train_global_loss: 141434.0406; train_optim_loss: 141434.0406; val_kl_reg_loss: 292.1057; val_edge_recon_loss: 2410.3650; val_gene_expr_recon_loss: 158550.1719; val_lambda_latent_adj_recon_loss: 2487.4917; val_lambda_latent_contrastive_instanceloss: 6.4638; val_lambda_latent_contrastive_clusterloss: 3.3449; val_global_loss: 163749.9375; val_optim_loss: 163749.9375
# Epoch 19/100 |███-----------------| 19.0% val_auroc_score: 0.9344; val_auprc_score: 0.9122; val_best_acc_score: 0.8751; val_best_f1_score: 0.8817; train_kl_reg_loss: 329.8618; train_edge_recon_loss: 4445.3811; train_gene_expr_recon_loss: 125951.5391; train_lambda_latent_adj_recon_loss: 2282.7358; train_lambda_latent_contrastive_instanceloss: 6.5870; train_lambda_latent_contrastive_clusterloss: 3.4002; train_global_loss: 133019.5016; train_optim_loss: 133019.5016; val_kl_reg_loss: 286.5831; val_edge_recon_loss: 2399.5713; val_gene_expr_recon_loss: 142877.5312; val_lambda_latent_adj_recon_loss: 2569.2727; val_lambda_latent_contrastive_instanceloss: 6.5155; val_lambda_latent_contrastive_clusterloss: 3.3541; val_global_loss: 148142.8281; val_optim_loss: 148142.8281
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1e-05.
#
# Epoch 20/100 |████----------------| 20.0% val_auroc_score: 0.9338; val_auprc_score: 0.9144; val_best_acc_score: 0.8745; val_best_f1_score: 0.8809; train_kl_reg_loss: 333.8603; train_edge_recon_loss: 4448.2522; train_gene_expr_recon_loss: 132324.9516; train_lambda_latent_adj_recon_loss: 2232.5954; train_lambda_latent_contrastive_instanceloss: 6.5712; train_lambda_latent_contrastive_clusterloss: 3.3907; train_global_loss: 139349.6187; train_optim_loss: 139349.6187; val_kl_reg_loss: 269.3992; val_edge_recon_loss: 2379.6375; val_gene_expr_recon_loss: 132117.9375; val_lambda_latent_adj_recon_loss: 2390.7290; val_lambda_latent_contrastive_instanceloss: 6.5115; val_lambda_latent_contrastive_clusterloss: 3.3440; val_global_loss: 137167.5625; val_optim_loss: 137167.5625
# Epoch 21/100 |████----------------| 21.0% val_auroc_score: 0.9291; val_auprc_score: 0.9042; val_best_acc_score: 0.8662; val_best_f1_score: 0.8755; train_kl_reg_loss: 342.8077; train_edge_recon_loss: 4432.4706; train_gene_expr_recon_loss: 125193.0078; train_lambda_latent_adj_recon_loss: 2297.8619; train_lambda_latent_contrastive_instanceloss: 6.5774; train_lambda_latent_contrastive_clusterloss: 3.3966; train_global_loss: 132276.1203; train_optim_loss: 132276.1203; val_kl_reg_loss: 282.6758; val_edge_recon_loss: 2399.8406; val_gene_expr_recon_loss: 122923.7344; val_lambda_latent_adj_recon_loss: 2379.8467; val_lambda_latent_contrastive_instanceloss: 6.4854; val_lambda_latent_contrastive_clusterloss: 3.3426; val_global_loss: 127995.9219; val_optim_loss: 127995.9219
# Epoch 22/100 |████----------------| 22.0% val_auroc_score: 0.9308; val_auprc_score: 0.9029; val_best_acc_score: 0.8677; val_best_f1_score: 0.8771; train_kl_reg_loss: 338.1169; train_edge_recon_loss: 4435.5758; train_gene_expr_recon_loss: 120468.3172; train_lambda_latent_adj_recon_loss: 2250.6539; train_lambda_latent_contrastive_instanceloss: 6.5559; train_lambda_latent_contrastive_clusterloss: 3.3842; train_global_loss: 127502.6078; train_optim_loss: 127502.6078; val_kl_reg_loss: 283.2994; val_edge_recon_loss: 2388.0344; val_gene_expr_recon_loss: 138436.2969; val_lambda_latent_adj_recon_loss: 2356.0044; val_lambda_latent_contrastive_instanceloss: 6.5193; val_lambda_latent_contrastive_clusterloss: 3.3531; val_global_loss: 143473.5000; val_optim_loss: 143473.5000
# Epoch 23/100 |████----------------| 23.0% val_auroc_score: 0.9290; val_auprc_score: 0.9024; val_best_acc_score: 0.8693; val_best_f1_score: 0.8776; train_kl_reg_loss: 335.0814; train_edge_recon_loss: 4437.0610; train_gene_expr_recon_loss: 132275.6219; train_lambda_latent_adj_recon_loss: 2286.4305; train_lambda_latent_contrastive_instanceloss: 6.5653; train_lambda_latent_contrastive_clusterloss: 3.3866; train_global_loss: 139344.1500; train_optim_loss: 139344.1500; val_kl_reg_loss: 284.2576; val_edge_recon_loss: 2396.5728; val_gene_expr_recon_loss: 138773.7188; val_lambda_latent_adj_recon_loss: 2435.1794; val_lambda_latent_contrastive_instanceloss: 6.5084; val_lambda_latent_contrastive_clusterloss: 3.3483; val_global_loss: 143899.5781; val_optim_loss: 143899.5781
# Epoch 24/100 |████----------------| 24.0% val_auroc_score: 0.9368; val_auprc_score: 0.9178; val_best_acc_score: 0.8745; val_best_f1_score: 0.8835; train_kl_reg_loss: 329.4824; train_edge_recon_loss: 4436.6391; train_gene_expr_recon_loss: 121510.0547; train_lambda_latent_adj_recon_loss: 2305.3902; train_lambda_latent_contrastive_instanceloss: 6.5638; train_lambda_latent_contrastive_clusterloss: 3.3906; train_global_loss: 128591.5188; train_optim_loss: 128591.5188; val_kl_reg_loss: 283.0530; val_edge_recon_loss: 2394.6345; val_gene_expr_recon_loss: 152474.4688; val_lambda_latent_adj_recon_loss: 2567.2725; val_lambda_latent_contrastive_instanceloss: 6.5018; val_lambda_latent_contrastive_clusterloss: 3.3558; val_global_loss: 157729.2812; val_optim_loss: 157729.2812
# Epoch 25/100 |█████---------------| 25.0% val_auroc_score: 0.9345; val_auprc_score: 0.9137; val_best_acc_score: 0.8711; val_best_f1_score: 0.8803; train_kl_reg_loss: 332.7108; train_edge_recon_loss: 4443.7033; train_gene_expr_recon_loss: 125055.9984; train_lambda_latent_adj_recon_loss: 2289.7609; train_lambda_latent_contrastive_instanceloss: 6.5515; train_lambda_latent_contrastive_clusterloss: 3.3848; train_global_loss: 132132.1109; train_optim_loss: 132132.1109; val_kl_reg_loss: 269.2527; val_edge_recon_loss: 2402.3640; val_gene_expr_recon_loss: 122545.6562; val_lambda_latent_adj_recon_loss: 2390.9089; val_lambda_latent_contrastive_instanceloss: 6.5430; val_lambda_latent_contrastive_clusterloss: 3.3534; val_global_loss: 127618.0781; val_optim_loss: 127618.0781
# Epoch 26/100 |█████---------------| 26.0% val_auroc_score: 0.9298; val_auprc_score: 0.9093; val_best_acc_score: 0.8719; val_best_f1_score: 0.8798; train_kl_reg_loss: 347.2950; train_edge_recon_loss: 4440.9486; train_gene_expr_recon_loss: 140192.4109; train_lambda_latent_adj_recon_loss: 2320.2882; train_lambda_latent_contrastive_instanceloss: 6.5442; train_lambda_latent_contrastive_clusterloss: 3.3864; train_global_loss: 147310.8719; train_optim_loss: 147310.8719; val_kl_reg_loss: 278.3795; val_edge_recon_loss: 2395.0715; val_gene_expr_recon_loss: 136270.7969; val_lambda_latent_adj_recon_loss: 2431.6064; val_lambda_latent_contrastive_instanceloss: 6.4981; val_lambda_latent_contrastive_clusterloss: 3.3461; val_global_loss: 141385.7031; val_optim_loss: 141385.7031
# Epoch 27/100 |█████---------------| 27.0% val_auroc_score: 0.9327; val_auprc_score: 0.9140; val_best_acc_score: 0.8662; val_best_f1_score: 0.8748; train_kl_reg_loss: 338.6532; train_edge_recon_loss: 4430.8464; train_gene_expr_recon_loss: 130468.8844; train_lambda_latent_adj_recon_loss: 2291.1844; train_lambda_latent_contrastive_instanceloss: 6.5978; train_lambda_latent_contrastive_clusterloss: 3.4089; train_global_loss: 137539.5734; train_optim_loss: 137539.5734; val_kl_reg_loss: 280.6113; val_edge_recon_loss: 2413.4036; val_gene_expr_recon_loss: 123144.2031; val_lambda_latent_adj_recon_loss: 2457.4231; val_lambda_latent_contrastive_instanceloss: 6.5079; val_lambda_latent_contrastive_clusterloss: 3.3433; val_global_loss: 128305.4922; val_optim_loss: 128305.4922
# Epoch 28/100 |█████---------------| 28.0% val_auroc_score: 0.9267; val_auprc_score: 0.9018; val_best_acc_score: 0.8601; val_best_f1_score: 0.8690; train_kl_reg_loss: 330.7948; train_edge_recon_loss: 4433.2036; train_gene_expr_recon_loss: 137524.2250; train_lambda_latent_adj_recon_loss: 2282.2872; train_lambda_latent_contrastive_instanceloss: 6.5571; train_lambda_latent_contrastive_clusterloss: 3.3886; train_global_loss: 144580.4562; train_optim_loss: 144580.4562; val_kl_reg_loss: 274.6053; val_edge_recon_loss: 2403.9382; val_gene_expr_recon_loss: 122772.5469; val_lambda_latent_adj_recon_loss: 2375.5305; val_lambda_latent_contrastive_instanceloss: 6.5285; val_lambda_latent_contrastive_clusterloss: 3.3557; val_global_loss: 127836.5156; val_optim_loss: 127836.5156
# Epoch 29/100 |█████---------------| 29.0% val_auroc_score: 0.9337; val_auprc_score: 0.9045; val_best_acc_score: 0.8704; val_best_f1_score: 0.8781; train_kl_reg_loss: 344.0010; train_edge_recon_loss: 4428.3631; train_gene_expr_recon_loss: 131234.6984; train_lambda_latent_adj_recon_loss: 2301.8007; train_lambda_latent_contrastive_instanceloss: 6.5536; train_lambda_latent_contrastive_clusterloss: 3.3826; train_global_loss: 138318.7984; train_optim_loss: 138318.7984; val_kl_reg_loss: 288.6628; val_edge_recon_loss: 2387.6731; val_gene_expr_recon_loss: 161859.7344; val_lambda_latent_adj_recon_loss: 2420.2026; val_lambda_latent_contrastive_instanceloss: 6.5291; val_lambda_latent_contrastive_clusterloss: 3.3446; val_global_loss: 166966.1406; val_optim_loss: 166966.1406
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1.0000000000000002e-06.
#
# Epoch 30/100 |██████--------------| 30.0% val_auroc_score: 0.9298; val_auprc_score: 0.9067; val_best_acc_score: 0.8680; val_best_f1_score: 0.8754; train_kl_reg_loss: 338.2335; train_edge_recon_loss: 4438.0196; train_gene_expr_recon_loss: 139419.0156; train_lambda_latent_adj_recon_loss: 2288.7206; train_lambda_latent_contrastive_instanceloss: 6.5488; train_lambda_latent_contrastive_clusterloss: 3.3853; train_global_loss: 146493.9219; train_optim_loss: 146493.9219; val_kl_reg_loss: 287.0716; val_edge_recon_loss: 2411.0854; val_gene_expr_recon_loss: 148012.4219; val_lambda_latent_adj_recon_loss: 2307.3472; val_lambda_latent_contrastive_instanceloss: 6.5048; val_lambda_latent_contrastive_clusterloss: 3.3541; val_global_loss: 153027.7812; val_optim_loss: 153027.7812
# Epoch 31/100 |██████--------------| 31.0% val_auroc_score: 0.9298; val_auprc_score: 0.9023; val_best_acc_score: 0.8738; val_best_f1_score: 0.8828; train_kl_reg_loss: 335.9858; train_edge_recon_loss: 4431.9631; train_gene_expr_recon_loss: 130088.1656; train_lambda_latent_adj_recon_loss: 2248.1645; train_lambda_latent_contrastive_instanceloss: 6.5470; train_lambda_latent_contrastive_clusterloss: 3.3837; train_global_loss: 137114.2000; train_optim_loss: 137114.2000; val_kl_reg_loss: 280.1822; val_edge_recon_loss: 2384.8972; val_gene_expr_recon_loss: 135189.5625; val_lambda_latent_adj_recon_loss: 2487.2656; val_lambda_latent_contrastive_instanceloss: 6.5195; val_lambda_latent_contrastive_clusterloss: 3.3629; val_global_loss: 140351.7812; val_optim_loss: 140351.7812
# Epoch 32/100 |██████--------------| 32.0% val_auroc_score: 0.9322; val_auprc_score: 0.9128; val_best_acc_score: 0.8662; val_best_f1_score: 0.8751; train_kl_reg_loss: 330.6229; train_edge_recon_loss: 4429.3077; train_gene_expr_recon_loss: 122658.3391; train_lambda_latent_adj_recon_loss: 2290.5408; train_lambda_latent_contrastive_instanceloss: 6.5688; train_lambda_latent_contrastive_clusterloss: 3.3949; train_global_loss: 129718.7734; train_optim_loss: 129718.7734; val_kl_reg_loss: 290.2609; val_edge_recon_loss: 2402.5952; val_gene_expr_recon_loss: 134837.6719; val_lambda_latent_adj_recon_loss: 2366.4683; val_lambda_latent_contrastive_instanceloss: 6.4945; val_lambda_latent_contrastive_clusterloss: 3.3531; val_global_loss: 139906.8594; val_optim_loss: 139906.8594
# Epoch 33/100 |██████--------------| 33.0% val_auroc_score: 0.9244; val_auprc_score: 0.9011; val_best_acc_score: 0.8567; val_best_f1_score: 0.8684; train_kl_reg_loss: 338.3352; train_edge_recon_loss: 4445.6147; train_gene_expr_recon_loss: 129039.4406; train_lambda_latent_adj_recon_loss: 2273.2477; train_lambda_latent_contrastive_instanceloss: 6.5714; train_lambda_latent_contrastive_clusterloss: 3.3934; train_global_loss: 136106.6094; train_optim_loss: 136106.6094; val_kl_reg_loss: 281.2750; val_edge_recon_loss: 2410.8406; val_gene_expr_recon_loss: 157837.5781; val_lambda_latent_adj_recon_loss: 2449.2268; val_lambda_latent_contrastive_instanceloss: 6.4933; val_lambda_latent_contrastive_clusterloss: 3.3508; val_global_loss: 162988.7656; val_optim_loss: 162988.7656
#
# Stopping early: metric has not improved more than 0.0 in the last 8 epochs.
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Model training finished after 1 min 4 sec.
# Using best model state, which was in epoch 25.
#
# --- MODEL EVALUATION ---
# val AUROC score: 0.9261
# val AUPRC score: 0.8940
# val best accuracy score: 0.8614
# val best F1 score: 0.8737
# val MSE score: 6.7813

# %%
# Compute latent neighbor graph
latent_key = 'garfield_latent'
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)
# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %%
sc.pl.umap(model.adata, color=['rna:celltype'], show=True, size=3)

# %%
sc.pl.umap(model.adata, color=[ 'rna:celltype'], show=True, size=5, legend_loc='on data')

# %%
# Save trained model
model_folder_path = f"{workdir}/model"
os.makedirs(model_folder_path, exist_ok=True)

model.save(dir_path=model_folder_path,
           overwrite=True,
           save_adata=True,
           adata_file_name="adata_ref.h5ad")
# Out:
# Pickle failed with error: Can't pickle local object 'WeakSet.__init__.<locals>._remove', switching to dill...
# Model saved successfully using dill at /home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_multiome_10xpbmc3k/model/attr.pkl
