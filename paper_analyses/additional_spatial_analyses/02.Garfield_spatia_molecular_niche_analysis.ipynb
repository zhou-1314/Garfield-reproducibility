# %% [markdown]
# ## Spatial molecular niche discovery (single-modality with multiple batches)

# %% [markdown]
# Here we will use seqFISH Mouse Organogenesis datasets as an example to illustrate how Garfield performs spatial molecular niche discovery for multiple batches. Data access: https://marionilab.cruk.cam.ac.uk/SpatialMouseAtlas/.

# %%
import os
import pandas as pd
import numpy as np

os.chdir('/data2/zhouwg_data/project/Garfield')
os.getcwd()
# Out:
# '/data2/zhouwg_data/project/Garfield'

# %%
# load packages
import os
import warnings
import Garfield as gf
import scanpy as sc
from mudata import MuData
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

gf.__version__
# Out:
# '0.3.1'

# %%
# Load data
# Define paths
st_data_folder_path = "/home/zhouweige/zhouwg_data/project/Garfield_tutorials/data" # spatially resolved transcriptomics data
dataset = "seqfish_mouse_organogenesis"
cell_type_key = "celltype_mapped_refined"

adata_list = []
batch_indeces = list(np.arange(6) + 1)
batches = ["embryo1_z2",
           "embryo1_z5",
           "embryo2_z2",
           "embryo2_z5",
           "embryo3_z2",
           "embryo3_z5"]

for batch_idx, batch in zip(batch_indeces, batches):
    adata = sc.read_h5ad(f"{st_data_folder_path}/{dataset}_batch{batch_idx}.h5ad")
    adata.var_names_make_unique(join="++")
    # make spot name unique
    # adata.obs_names = [x+'_'+batch for x in adata.obs_names]
    adata_list.append(adata)

# %%
import anndata as ad

adata_concat = ad.concat(adata_list, label="slice_name", keys=batches)
adata_concat
# Out:
# AnnData object with n_obs × n_vars = 52568 × 351
#     obs: 'Area', 'celltype_mapped_refined', 'sample', 'batch', 'slice_name'
#     obsm: 'spatial'
#     layers: 'counts'

# %%
# check the batch information of this dataset
adata_concat.obs['batch'].value_counts()
# Out:
# batch
# embryo3_z2    11169
# embryo1_z2    10150
# embryo3_z5     9408
# embryo2_z2     7661
# embryo1_z5     7656
# embryo2_z5     6524
# Name: count, dtype: int64

# %%
# Ensure adata.X is counts.
adata_concat.X = adata_concat.layers['counts'].copy()
adata_concat.X.max()
# Out:
# 141.0

# %% [markdown]
# ## Integrating spatially resolved transcriptomics data using Garfield

# %% [markdown]
# For spatial niche discovery from spatially resolved transcriptomics data, we should adjust the following paremeters,
# and all parameter introductions can be found in [Garfield_Model_Parameters](https://github.com/zhou-1314/Garfield/blob/main/Garfield_Model_Parameters.md).

# %%
# set workdir
workdir = '/home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_spRNA_embryo'
gf.settings.set_workdir(workdir)

### modify parameter
user_config = dict(
    ## Input options
    adata_list=adata_concat,
    profile='spatial',
    data_type='single-modal',
    sample_col='batch',
    weight=0.5,
    ## Preprocessing options
    graph_const_method='Squidpy', # mu_std, Radius, KNN, Squidpy
    used_hvg=True,
    min_cells=3,
    min_features=0,
    keep_mt=False,
    target_sum=1e4,
    rna_n_top_features=3000,
    n_components=50,
    n_neighbors=5,
    metric='euclidean',
    svd_solver='arpack',
    # datasets
    used_pca_feat=False,
    adj_key='connectivities', 
    # data split parameters
    edge_val_ratio=0.1,
    edge_test_ratio=0.,
    node_val_ratio=0.1,
    node_test_ratio=0.,
    ## Model options
    augment_type='svd',
    svd_q=5,
    use_FCencoder=False,
    conv_type='GATv2Conv', # GAT or GATv2Conv or GCN
    gnn_layer=2,
    hidden_dims=[128, 128],
    bottle_neck_neurons=20,
    cluster_num=20,
    drop_feature_rate=0.2, 
    drop_edge_rate=0.2,
    num_heads=3,
    dropout=0.2,
    concat=True,
    used_edge_weight=True,
    used_DSBN=False,
    used_mmd=False,
    # data loader parameters
    num_neighbors=5,
    loaders_n_hops=2,
    edge_batch_size=4096,
    node_batch_size=128, # None
    # loss parameters
    include_edge_recon_loss=True,
    include_gene_expr_recon_loss=True,
    lambda_latent_contrastive_instanceloss=1.0,
    lambda_latent_contrastive_clusterloss=0.5,
    lambda_gene_expr_recon=300., # 300
    lambda_edge_recon=500., #
    lambda_omics_recon_mmd_loss=0.2,
    # train parameters
    n_epochs_no_edge_recon=0,
    learning_rate=0.001,
    weight_decay=1e-05,
    gradient_clipping=5,
    # other parameters
    latent_key='garfield_latent',
    reload_best_model=True,
    use_early_stopping=True,
    early_stopping_kwargs=None,
    monitor=True,
    seed=2024,
    verbose=True
)
dict_config = gf.settings.set_gf_params(user_config)
# Out:
# Saving results in: /home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_spRNA_embryo

# %%
from Garfield.model import Garfield

# Initialize model
model = Garfield(dict_config)
# Out:
# --- DATA LOADING AND PREPROCESSING ---
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.2

# %%
# Train model
model.train()
# Out:
# --- INITIALIZING TRAINER ---
# Number of training nodes: 47311
# Number of validation nodes: 5257
# Number of training edges: 293496
# Number of validation edges: 32610
# Edge batch size: 4096
# Node batch size: 128
#
# --- MODEL TRAINING ---
# Epoch 1/100 |--------------------| 1.0% val_auroc_score: 0.6245; val_auprc_score: 0.6256; val_best_acc_score: 0.5803; val_best_f1_score: 0.6761; train_kl_reg_loss: 48.9225; train_edge_recon_loss: 352.0153; train_gene_expr_recon_loss: 1071.4586; train_lambda_latent_contrastive_instanceloss: 7.2582; train_lambda_latent_contrastive_clusterloss: 3.6662; train_global_loss: 1483.3208; train_optim_loss: 1483.3208; val_kl_reg_loss: 5.3401; val_edge_recon_loss: 350.1014; val_gene_expr_recon_loss: 949.4852; val_lambda_latent_contrastive_instanceloss: 6.9873; val_lambda_latent_contrastive_clusterloss: 3.5448; val_global_loss: 1315.4587; val_optim_loss: 1315.4587
# Epoch 2/100 |--------------------| 2.0% val_auroc_score: 0.7611; val_auprc_score: 0.7631; val_best_acc_score: 0.6966; val_best_f1_score: 0.7158; train_kl_reg_loss: 9.2394; train_edge_recon_loss: 343.5369; train_gene_expr_recon_loss: 967.2723; train_lambda_latent_contrastive_instanceloss: 7.1455; train_lambda_latent_contrastive_clusterloss: 3.5602; train_global_loss: 1330.7543; train_optim_loss: 1330.7543; val_kl_reg_loss: 10.5147; val_edge_recon_loss: 311.4475; val_gene_expr_recon_loss: 917.1376; val_lambda_latent_contrastive_instanceloss: 6.7608; val_lambda_latent_contrastive_clusterloss: 3.2774; val_global_loss: 1249.1380; val_optim_loss: 1249.1380
# Epoch 3/100 |--------------------| 3.0% val_auroc_score: 0.8211; val_auprc_score: 0.8296; val_best_acc_score: 0.7575; val_best_f1_score: 0.7560; train_kl_reg_loss: 15.0741; train_edge_recon_loss: 332.6905; train_gene_expr_recon_loss: 939.7293; train_lambda_latent_contrastive_instanceloss: 6.8984; train_lambda_latent_contrastive_clusterloss: 3.3119; train_global_loss: 1297.7041; train_optim_loss: 1297.7041; val_kl_reg_loss: 14.3128; val_edge_recon_loss: 298.9689; val_gene_expr_recon_loss: 903.2621; val_lambda_latent_contrastive_instanceloss: 6.6091; val_lambda_latent_contrastive_clusterloss: 3.0310; val_global_loss: 1226.1840; val_optim_loss: 1226.1840
# Epoch 4/100 |--------------------| 4.0% val_auroc_score: 0.8556; val_auprc_score: 0.8675; val_best_acc_score: 0.7972; val_best_f1_score: 0.7883; train_kl_reg_loss: 20.0290; train_edge_recon_loss: 325.2968; train_gene_expr_recon_loss: 917.7006; train_lambda_latent_contrastive_instanceloss: 6.7739; train_lambda_latent_contrastive_clusterloss: 3.1074; train_global_loss: 1272.9077; train_optim_loss: 1272.9077; val_kl_reg_loss: 16.8224; val_edge_recon_loss: 292.4069; val_gene_expr_recon_loss: 880.9406; val_lambda_latent_contrastive_instanceloss: 6.5118; val_lambda_latent_contrastive_clusterloss: 2.7926; val_global_loss: 1199.4743; val_optim_loss: 1199.4743
# Epoch 5/100 |█-------------------| 5.0% val_auroc_score: 0.8650; val_auprc_score: 0.8805; val_best_acc_score: 0.8079; val_best_f1_score: 0.7967; train_kl_reg_loss: 22.5802; train_edge_recon_loss: 320.4389; train_gene_expr_recon_loss: 900.5375; train_lambda_latent_contrastive_instanceloss: 6.6967; train_lambda_latent_contrastive_clusterloss: 2.9480; train_global_loss: 1253.2014; train_optim_loss: 1253.2014; val_kl_reg_loss: 18.1127; val_edge_recon_loss: 289.1884; val_gene_expr_recon_loss: 868.9687; val_lambda_latent_contrastive_instanceloss: 6.4639; val_lambda_latent_contrastive_clusterloss: 2.6365; val_global_loss: 1185.3701; val_optim_loss: 1185.3701
# Epoch 6/100 |█-------------------| 6.0% val_auroc_score: 0.8680; val_auprc_score: 0.8850; val_best_acc_score: 0.8094; val_best_f1_score: 0.7994; train_kl_reg_loss: 24.9412; train_edge_recon_loss: 317.4675; train_gene_expr_recon_loss: 888.7605; train_lambda_latent_contrastive_instanceloss: 6.6502; train_lambda_latent_contrastive_clusterloss: 2.8457; train_global_loss: 1240.6651; train_optim_loss: 1240.6651; val_kl_reg_loss: 20.4932; val_edge_recon_loss: 288.9309; val_gene_expr_recon_loss: 855.6589; val_lambda_latent_contrastive_instanceloss: 6.4492; val_lambda_latent_contrastive_clusterloss: 2.5411; val_global_loss: 1174.0733; val_optim_loss: 1174.0733
# Epoch 7/100 |█-------------------| 7.0% val_auroc_score: 0.8729; val_auprc_score: 0.8881; val_best_acc_score: 0.8154; val_best_f1_score: 0.8051; train_kl_reg_loss: 26.4080; train_edge_recon_loss: 315.4289; train_gene_expr_recon_loss: 879.5295; train_lambda_latent_contrastive_instanceloss: 6.6112; train_lambda_latent_contrastive_clusterloss: 2.7382; train_global_loss: 1230.7158; train_optim_loss: 1230.7158; val_kl_reg_loss: 20.5121; val_edge_recon_loss: 286.9314; val_gene_expr_recon_loss: 846.7594; val_lambda_latent_contrastive_instanceloss: 6.4358; val_lambda_latent_contrastive_clusterloss: 2.4425; val_global_loss: 1163.0812; val_optim_loss: 1163.0812
# Epoch 8/100 |█-------------------| 8.0% val_auroc_score: 0.8756; val_auprc_score: 0.8935; val_best_acc_score: 0.8181; val_best_f1_score: 0.8073; train_kl_reg_loss: 27.6132; train_edge_recon_loss: 314.0285; train_gene_expr_recon_loss: 871.6136; train_lambda_latent_contrastive_instanceloss: 6.5865; train_lambda_latent_contrastive_clusterloss: 2.6352; train_global_loss: 1222.4770; train_optim_loss: 1222.4770; val_kl_reg_loss: 21.9217; val_edge_recon_loss: 287.3387; val_gene_expr_recon_loss: 836.2764; val_lambda_latent_contrastive_instanceloss: 6.4268; val_lambda_latent_contrastive_clusterloss: 2.3604; val_global_loss: 1154.3240; val_optim_loss: 1154.3240
# Epoch 9/100 |█-------------------| 9.0% val_auroc_score: 0.8822; val_auprc_score: 0.8992; val_best_acc_score: 0.8241; val_best_f1_score: 0.8142; train_kl_reg_loss: 29.3523; train_edge_recon_loss: 312.1593; train_gene_expr_recon_loss: 861.1828; train_lambda_latent_contrastive_instanceloss: 6.5715; train_lambda_latent_contrastive_clusterloss: 2.5650; train_global_loss: 1211.8309; train_optim_loss: 1211.8309; val_kl_reg_loss: 22.5858; val_edge_recon_loss: 285.8885; val_gene_expr_recon_loss: 826.3158; val_lambda_latent_contrastive_instanceloss: 6.4219; val_lambda_latent_contrastive_clusterloss: 2.3009; val_global_loss: 1143.5130; val_optim_loss: 1143.5130
# Epoch 10/100 |██------------------| 10.0% val_auroc_score: 0.8865; val_auprc_score: 0.9041; val_best_acc_score: 0.8274; val_best_f1_score: 0.8164; train_kl_reg_loss: 29.8323; train_edge_recon_loss: 311.1879; train_gene_expr_recon_loss: 853.5735; train_lambda_latent_contrastive_instanceloss: 6.5584; train_lambda_latent_contrastive_clusterloss: 2.5142; train_global_loss: 1203.6662; train_optim_loss: 1203.6662; val_kl_reg_loss: 23.4345; val_edge_recon_loss: 284.9723; val_gene_expr_recon_loss: 825.4358; val_lambda_latent_contrastive_instanceloss: 6.4207; val_lambda_latent_contrastive_clusterloss: 2.2755; val_global_loss: 1142.5389; val_optim_loss: 1142.5389
# Epoch 11/100 |██------------------| 11.0% val_auroc_score: 0.8888; val_auprc_score: 0.9055; val_best_acc_score: 0.8297; val_best_f1_score: 0.8197; train_kl_reg_loss: 30.4729; train_edge_recon_loss: 310.0617; train_gene_expr_recon_loss: 849.9261; train_lambda_latent_contrastive_instanceloss: 6.5427; train_lambda_latent_contrastive_clusterloss: 2.4691; train_global_loss: 1199.4726; train_optim_loss: 1199.4726; val_kl_reg_loss: 24.1751; val_edge_recon_loss: 284.7062; val_gene_expr_recon_loss: 821.2015; val_lambda_latent_contrastive_instanceloss: 6.4123; val_lambda_latent_contrastive_clusterloss: 2.2326; val_global_loss: 1138.7276; val_optim_loss: 1138.7276
# Epoch 12/100 |██------------------| 12.0% val_auroc_score: 0.8902; val_auprc_score: 0.9068; val_best_acc_score: 0.8298; val_best_f1_score: 0.8198; train_kl_reg_loss: 31.2115; train_edge_recon_loss: 309.4227; train_gene_expr_recon_loss: 844.2302; train_lambda_latent_contrastive_instanceloss: 6.5305; train_lambda_latent_contrastive_clusterloss: 2.4264; train_global_loss: 1193.8212; train_optim_loss: 1193.8212; val_kl_reg_loss: 24.7827; val_edge_recon_loss: 284.6221; val_gene_expr_recon_loss: 818.1973; val_lambda_latent_contrastive_instanceloss: 6.4028; val_lambda_latent_contrastive_clusterloss: 2.2020; val_global_loss: 1136.2070; val_optim_loss: 1136.2070
# Epoch 13/100 |██------------------| 13.0% val_auroc_score: 0.8926; val_auprc_score: 0.9085; val_best_acc_score: 0.8318; val_best_f1_score: 0.8208; train_kl_reg_loss: 31.8466; train_edge_recon_loss: 308.6350; train_gene_expr_recon_loss: 844.0042; train_lambda_latent_contrastive_instanceloss: 6.5242; train_lambda_latent_contrastive_clusterloss: 2.4057; train_global_loss: 1193.4157; train_optim_loss: 1193.4157; val_kl_reg_loss: 25.8677; val_edge_recon_loss: 284.4799; val_gene_expr_recon_loss: 815.4400; val_lambda_latent_contrastive_instanceloss: 6.4028; val_lambda_latent_contrastive_clusterloss: 2.1778; val_global_loss: 1134.3682; val_optim_loss: 1134.3682
# Epoch 14/100 |██------------------| 14.0% val_auroc_score: 0.8928; val_auprc_score: 0.9094; val_best_acc_score: 0.8330; val_best_f1_score: 0.8228; train_kl_reg_loss: 32.4952; train_edge_recon_loss: 307.9013; train_gene_expr_recon_loss: 839.1095; train_lambda_latent_contrastive_instanceloss: 6.5169; train_lambda_latent_contrastive_clusterloss: 2.3769; train_global_loss: 1188.3998; train_optim_loss: 1188.3998; val_kl_reg_loss: 26.9491; val_edge_recon_loss: 284.4999; val_gene_expr_recon_loss: 811.5780; val_lambda_latent_contrastive_instanceloss: 6.4018; val_lambda_latent_contrastive_clusterloss: 2.1540; val_global_loss: 1131.5828; val_optim_loss: 1131.5828
# Epoch 15/100 |███-----------------| 15.0% val_auroc_score: 0.8954; val_auprc_score: 0.9124; val_best_acc_score: 0.8354; val_best_f1_score: 0.8239; train_kl_reg_loss: 32.9020; train_edge_recon_loss: 307.5402; train_gene_expr_recon_loss: 837.0189; train_lambda_latent_contrastive_instanceloss: 6.5095; train_lambda_latent_contrastive_clusterloss: 2.3626; train_global_loss: 1186.3331; train_optim_loss: 1186.3331; val_kl_reg_loss: 26.7673; val_edge_recon_loss: 283.7411; val_gene_expr_recon_loss: 809.9678; val_lambda_latent_contrastive_instanceloss: 6.3947; val_lambda_latent_contrastive_clusterloss: 2.1398; val_global_loss: 1129.0108; val_optim_loss: 1129.0108
# Epoch 16/100 |███-----------------| 16.0% val_auroc_score: 0.8963; val_auprc_score: 0.9148; val_best_acc_score: 0.8367; val_best_f1_score: 0.8256; train_kl_reg_loss: 33.4276; train_edge_recon_loss: 307.0883; train_gene_expr_recon_loss: 835.2126; train_lambda_latent_contrastive_instanceloss: 6.5046; train_lambda_latent_contrastive_clusterloss: 2.3477; train_global_loss: 1184.5808; train_optim_loss: 1184.5808; val_kl_reg_loss: 28.4371; val_edge_recon_loss: 283.8637; val_gene_expr_recon_loss: 801.0080; val_lambda_latent_contrastive_instanceloss: 6.4051; val_lambda_latent_contrastive_clusterloss: 2.1291; val_global_loss: 1121.8429; val_optim_loss: 1121.8429
# Epoch 17/100 |███-----------------| 17.0% val_auroc_score: 0.8982; val_auprc_score: 0.9159; val_best_acc_score: 0.8395; val_best_f1_score: 0.8284; train_kl_reg_loss: 33.9041; train_edge_recon_loss: 306.6267; train_gene_expr_recon_loss: 833.1849; train_lambda_latent_contrastive_instanceloss: 6.4984; train_lambda_latent_contrastive_clusterloss: 2.3242; train_global_loss: 1182.5384; train_optim_loss: 1182.5384; val_kl_reg_loss: 28.1168; val_edge_recon_loss: 283.5145; val_gene_expr_recon_loss: 812.8453; val_lambda_latent_contrastive_instanceloss: 6.4001; val_lambda_latent_contrastive_clusterloss: 2.1376; val_global_loss: 1133.0142; val_optim_loss: 1133.0142
# Epoch 18/100 |███-----------------| 18.0% val_auroc_score: 0.8981; val_auprc_score: 0.9165; val_best_acc_score: 0.8398; val_best_f1_score: 0.8281; train_kl_reg_loss: 34.5247; train_edge_recon_loss: 306.2341; train_gene_expr_recon_loss: 829.3494; train_lambda_latent_contrastive_instanceloss: 6.4915; train_lambda_latent_contrastive_clusterloss: 2.3111; train_global_loss: 1178.9108; train_optim_loss: 1178.9108; val_kl_reg_loss: 29.3442; val_edge_recon_loss: 283.7335; val_gene_expr_recon_loss: 804.5933; val_lambda_latent_contrastive_instanceloss: 6.3902; val_lambda_latent_contrastive_clusterloss: 2.0997; val_global_loss: 1126.1608; val_optim_loss: 1126.1608
# Epoch 19/100 |███-----------------| 19.0% val_auroc_score: 0.8993; val_auprc_score: 0.9177; val_best_acc_score: 0.8402; val_best_f1_score: 0.8298; train_kl_reg_loss: 35.0954; train_edge_recon_loss: 305.9322; train_gene_expr_recon_loss: 826.9111; train_lambda_latent_contrastive_instanceloss: 6.4903; train_lambda_latent_contrastive_clusterloss: 2.2996; train_global_loss: 1176.7285; train_optim_loss: 1176.7285; val_kl_reg_loss: 29.4735; val_edge_recon_loss: 283.3523; val_gene_expr_recon_loss: 798.5341; val_lambda_latent_contrastive_instanceloss: 6.3947; val_lambda_latent_contrastive_clusterloss: 2.0981; val_global_loss: 1119.8527; val_optim_loss: 1119.8527
# Epoch 20/100 |████----------------| 20.0% val_auroc_score: 0.9015; val_auprc_score: 0.9179; val_best_acc_score: 0.8437; val_best_f1_score: 0.8324; train_kl_reg_loss: 35.3598; train_edge_recon_loss: 305.5532; train_gene_expr_recon_loss: 824.6824; train_lambda_latent_contrastive_instanceloss: 6.4853; train_lambda_latent_contrastive_clusterloss: 2.2839; train_global_loss: 1174.3646; train_optim_loss: 1174.3646; val_kl_reg_loss: 29.4106; val_edge_recon_loss: 282.6280; val_gene_expr_recon_loss: 795.6475; val_lambda_latent_contrastive_instanceloss: 6.3959; val_lambda_latent_contrastive_clusterloss: 2.1003; val_global_loss: 1116.1823; val_optim_loss: 1116.1823
# Epoch 21/100 |████----------------| 21.0% val_auroc_score: 0.9020; val_auprc_score: 0.9208; val_best_acc_score: 0.8438; val_best_f1_score: 0.8325; train_kl_reg_loss: 35.6074; train_edge_recon_loss: 305.3005; train_gene_expr_recon_loss: 823.3943; train_lambda_latent_contrastive_instanceloss: 6.4844; train_lambda_latent_contrastive_clusterloss: 2.2728; train_global_loss: 1173.0593; train_optim_loss: 1173.0593; val_kl_reg_loss: 30.1352; val_edge_recon_loss: 283.4966; val_gene_expr_recon_loss: 800.6464; val_lambda_latent_contrastive_instanceloss: 6.3853; val_lambda_latent_contrastive_clusterloss: 2.0773; val_global_loss: 1122.7407; val_optim_loss: 1122.7407
# Epoch 22/100 |████----------------| 22.0% val_auroc_score: 0.9044; val_auprc_score: 0.9216; val_best_acc_score: 0.8443; val_best_f1_score: 0.8345; train_kl_reg_loss: 35.9480; train_edge_recon_loss: 305.1506; train_gene_expr_recon_loss: 820.7615; train_lambda_latent_contrastive_instanceloss: 6.4803; train_lambda_latent_contrastive_clusterloss: 2.2680; train_global_loss: 1170.6083; train_optim_loss: 1170.6083; val_kl_reg_loss: 32.4997; val_edge_recon_loss: 283.2495; val_gene_expr_recon_loss: 795.4853; val_lambda_latent_contrastive_instanceloss: 6.3872; val_lambda_latent_contrastive_clusterloss: 2.0701; val_global_loss: 1119.6919; val_optim_loss: 1119.6919
# Epoch 23/100 |████----------------| 23.0% val_auroc_score: 0.9027; val_auprc_score: 0.9205; val_best_acc_score: 0.8441; val_best_f1_score: 0.8328; train_kl_reg_loss: 36.1006; train_edge_recon_loss: 304.8667; train_gene_expr_recon_loss: 819.2862; train_lambda_latent_contrastive_instanceloss: 6.4812; train_lambda_latent_contrastive_clusterloss: 2.2608; train_global_loss: 1168.9955; train_optim_loss: 1168.9955; val_kl_reg_loss: 32.0770; val_edge_recon_loss: 283.4254; val_gene_expr_recon_loss: 792.0132; val_lambda_latent_contrastive_instanceloss: 6.3915; val_lambda_latent_contrastive_clusterloss: 2.0697; val_global_loss: 1115.9769; val_optim_loss: 1115.9769
# Epoch 24/100 |████----------------| 24.0% val_auroc_score: 0.9021; val_auprc_score: 0.9213; val_best_acc_score: 0.8437; val_best_f1_score: 0.8329; train_kl_reg_loss: 36.3015; train_edge_recon_loss: 304.6686; train_gene_expr_recon_loss: 819.5751; train_lambda_latent_contrastive_instanceloss: 6.4768; train_lambda_latent_contrastive_clusterloss: 2.2489; train_global_loss: 1169.2708; train_optim_loss: 1169.2708; val_kl_reg_loss: 31.7727; val_edge_recon_loss: 283.4487; val_gene_expr_recon_loss: 791.7921; val_lambda_latent_contrastive_instanceloss: 6.3896; val_lambda_latent_contrastive_clusterloss: 2.0598; val_global_loss: 1115.4630; val_optim_loss: 1115.4630
# Epoch 25/100 |█████---------------| 25.0% val_auroc_score: 0.9049; val_auprc_score: 0.9208; val_best_acc_score: 0.8452; val_best_f1_score: 0.8342; train_kl_reg_loss: 36.4035; train_edge_recon_loss: 304.6312; train_gene_expr_recon_loss: 817.7562; train_lambda_latent_contrastive_instanceloss: 6.4729; train_lambda_latent_contrastive_clusterloss: 2.2448; train_global_loss: 1167.5087; train_optim_loss: 1167.5087; val_kl_reg_loss: 31.3383; val_edge_recon_loss: 282.8541; val_gene_expr_recon_loss: 794.4454; val_lambda_latent_contrastive_instanceloss: 6.3893; val_lambda_latent_contrastive_clusterloss: 2.0540; val_global_loss: 1117.0811; val_optim_loss: 1117.0811
# Epoch 26/100 |█████---------------| 26.0% val_auroc_score: 0.9052; val_auprc_score: 0.9213; val_best_acc_score: 0.8441; val_best_f1_score: 0.8338; train_kl_reg_loss: 36.4735; train_edge_recon_loss: 304.2842; train_gene_expr_recon_loss: 817.1609; train_lambda_latent_contrastive_instanceloss: 6.4716; train_lambda_latent_contrastive_clusterloss: 2.2324; train_global_loss: 1166.6225; train_optim_loss: 1166.6225; val_kl_reg_loss: 31.0324; val_edge_recon_loss: 283.1481; val_gene_expr_recon_loss: 794.9415; val_lambda_latent_contrastive_instanceloss: 6.3879; val_lambda_latent_contrastive_clusterloss: 2.0565; val_global_loss: 1117.5664; val_optim_loss: 1117.5664
# Epoch 27/100 |█████---------------| 27.0% val_auroc_score: 0.9061; val_auprc_score: 0.9222; val_best_acc_score: 0.8460; val_best_f1_score: 0.8346; train_kl_reg_loss: 36.6506; train_edge_recon_loss: 304.1514; train_gene_expr_recon_loss: 813.9957; train_lambda_latent_contrastive_instanceloss: 6.4682; train_lambda_latent_contrastive_clusterloss: 2.2290; train_global_loss: 1163.4950; train_optim_loss: 1163.4950; val_kl_reg_loss: 31.9802; val_edge_recon_loss: 282.3567; val_gene_expr_recon_loss: 793.6771; val_lambda_latent_contrastive_instanceloss: 6.3864; val_lambda_latent_contrastive_clusterloss: 2.0411; val_global_loss: 1116.4415; val_optim_loss: 1116.4415
# Epoch 28/100 |█████---------------| 28.0% val_auroc_score: 0.9066; val_auprc_score: 0.9234; val_best_acc_score: 0.8451; val_best_f1_score: 0.8341; train_kl_reg_loss: 36.7683; train_edge_recon_loss: 303.8959; train_gene_expr_recon_loss: 814.4566; train_lambda_latent_contrastive_instanceloss: 6.4681; train_lambda_latent_contrastive_clusterloss: 2.2205; train_global_loss: 1163.8094; train_optim_loss: 1163.8094; val_kl_reg_loss: 31.6867; val_edge_recon_loss: 282.4283; val_gene_expr_recon_loss: 790.9586; val_lambda_latent_contrastive_instanceloss: 6.3860; val_lambda_latent_contrastive_clusterloss: 2.0551; val_global_loss: 1113.5147; val_optim_loss: 1113.5147
# Epoch 29/100 |█████---------------| 29.0% val_auroc_score: 0.9057; val_auprc_score: 0.9225; val_best_acc_score: 0.8453; val_best_f1_score: 0.8336; train_kl_reg_loss: 36.9694; train_edge_recon_loss: 303.7969; train_gene_expr_recon_loss: 812.9539; train_lambda_latent_contrastive_instanceloss: 6.4654; train_lambda_latent_contrastive_clusterloss: 2.2146; train_global_loss: 1162.4003; train_optim_loss: 1162.4003; val_kl_reg_loss: 32.0392; val_edge_recon_loss: 283.0202; val_gene_expr_recon_loss: 794.6514; val_lambda_latent_contrastive_instanceloss: 6.3823; val_lambda_latent_contrastive_clusterloss: 2.0473; val_global_loss: 1118.1404; val_optim_loss: 1118.1404
# Epoch 30/100 |██████--------------| 30.0% val_auroc_score: 0.9073; val_auprc_score: 0.9242; val_best_acc_score: 0.8457; val_best_f1_score: 0.8360; train_kl_reg_loss: 37.1404; train_edge_recon_loss: 303.8517; train_gene_expr_recon_loss: 812.1034; train_lambda_latent_contrastive_instanceloss: 6.4654; train_lambda_latent_contrastive_clusterloss: 2.2071; train_global_loss: 1161.7681; train_optim_loss: 1161.7681; val_kl_reg_loss: 34.2503; val_edge_recon_loss: 282.5478; val_gene_expr_recon_loss: 788.7985; val_lambda_latent_contrastive_instanceloss: 6.3804; val_lambda_latent_contrastive_clusterloss: 2.0278; val_global_loss: 1114.0047; val_optim_loss: 1114.0047
# Epoch 31/100 |██████--------------| 31.0% val_auroc_score: 0.9073; val_auprc_score: 0.9238; val_best_acc_score: 0.8464; val_best_f1_score: 0.8355; train_kl_reg_loss: 37.5186; train_edge_recon_loss: 303.5820; train_gene_expr_recon_loss: 813.1038; train_lambda_latent_contrastive_instanceloss: 6.4627; train_lambda_latent_contrastive_clusterloss: 2.2062; train_global_loss: 1162.8733; train_optim_loss: 1162.8733; val_kl_reg_loss: 32.6598; val_edge_recon_loss: 282.6791; val_gene_expr_recon_loss: 792.8545; val_lambda_latent_contrastive_instanceloss: 6.3849; val_lambda_latent_contrastive_clusterloss: 2.0377; val_global_loss: 1116.6160; val_optim_loss: 1116.6160
# Epoch 32/100 |██████--------------| 32.0% val_auroc_score: 0.9085; val_auprc_score: 0.9248; val_best_acc_score: 0.8470; val_best_f1_score: 0.8361; train_kl_reg_loss: 37.5617; train_edge_recon_loss: 303.5070; train_gene_expr_recon_loss: 809.0612; train_lambda_latent_contrastive_instanceloss: 6.4593; train_lambda_latent_contrastive_clusterloss: 2.1993; train_global_loss: 1158.7885; train_optim_loss: 1158.7885; val_kl_reg_loss: 32.0863; val_edge_recon_loss: 282.4334; val_gene_expr_recon_loss: 790.8577; val_lambda_latent_contrastive_instanceloss: 6.3854; val_lambda_latent_contrastive_clusterloss: 2.0328; val_global_loss: 1113.7955; val_optim_loss: 1113.7955
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 0.0001.
#
# Epoch 33/100 |██████--------------| 33.0% val_auroc_score: 0.9073; val_auprc_score: 0.9225; val_best_acc_score: 0.8469; val_best_f1_score: 0.8359; train_kl_reg_loss: 37.6440; train_edge_recon_loss: 303.2470; train_gene_expr_recon_loss: 808.1483; train_lambda_latent_contrastive_instanceloss: 6.4592; train_lambda_latent_contrastive_clusterloss: 2.1916; train_global_loss: 1157.6901; train_optim_loss: 1157.6901; val_kl_reg_loss: 33.0913; val_edge_recon_loss: 282.7398; val_gene_expr_recon_loss: 787.8344; val_lambda_latent_contrastive_instanceloss: 6.3831; val_lambda_latent_contrastive_clusterloss: 2.0317; val_global_loss: 1112.0802; val_optim_loss: 1112.0802
# Epoch 34/100 |██████--------------| 34.0% val_auroc_score: 0.9090; val_auprc_score: 0.9248; val_best_acc_score: 0.8477; val_best_f1_score: 0.8370; train_kl_reg_loss: 37.7612; train_edge_recon_loss: 303.3624; train_gene_expr_recon_loss: 806.9579; train_lambda_latent_contrastive_instanceloss: 6.4582; train_lambda_latent_contrastive_clusterloss: 2.1905; train_global_loss: 1156.7303; train_optim_loss: 1156.7303; val_kl_reg_loss: 32.8592; val_edge_recon_loss: 282.3032; val_gene_expr_recon_loss: 786.7342; val_lambda_latent_contrastive_instanceloss: 6.3861; val_lambda_latent_contrastive_clusterloss: 2.0310; val_global_loss: 1110.3137; val_optim_loss: 1110.3137
# Epoch 35/100 |███████-------------| 35.0% val_auroc_score: 0.9076; val_auprc_score: 0.9235; val_best_acc_score: 0.8465; val_best_f1_score: 0.8356; train_kl_reg_loss: 37.8158; train_edge_recon_loss: 303.0671; train_gene_expr_recon_loss: 805.4594; train_lambda_latent_contrastive_instanceloss: 6.4554; train_lambda_latent_contrastive_clusterloss: 2.1852; train_global_loss: 1154.9831; train_optim_loss: 1154.9831; val_kl_reg_loss: 33.5545; val_edge_recon_loss: 282.6499; val_gene_expr_recon_loss: 786.7158; val_lambda_latent_contrastive_instanceloss: 6.3780; val_lambda_latent_contrastive_clusterloss: 2.0253; val_global_loss: 1111.3235; val_optim_loss: 1111.3235
# Epoch 36/100 |███████-------------| 36.0% val_auroc_score: 0.9094; val_auprc_score: 0.9254; val_best_acc_score: 0.8483; val_best_f1_score: 0.8377; train_kl_reg_loss: 37.9716; train_edge_recon_loss: 303.3377; train_gene_expr_recon_loss: 805.8595; train_lambda_latent_contrastive_instanceloss: 6.4566; train_lambda_latent_contrastive_clusterloss: 2.1843; train_global_loss: 1155.8097; train_optim_loss: 1155.8097; val_kl_reg_loss: 33.1922; val_edge_recon_loss: 282.1612; val_gene_expr_recon_loss: 787.8036; val_lambda_latent_contrastive_instanceloss: 6.3725; val_lambda_latent_contrastive_clusterloss: 2.0150; val_global_loss: 1111.5444; val_optim_loss: 1111.5444
# Epoch 37/100 |███████-------------| 37.0% val_auroc_score: 0.9082; val_auprc_score: 0.9237; val_best_acc_score: 0.8475; val_best_f1_score: 0.8368; train_kl_reg_loss: 37.7763; train_edge_recon_loss: 303.2815; train_gene_expr_recon_loss: 806.4834; train_lambda_latent_contrastive_instanceloss: 6.4558; train_lambda_latent_contrastive_clusterloss: 2.1866; train_global_loss: 1156.1836; train_optim_loss: 1156.1836; val_kl_reg_loss: 33.0760; val_edge_recon_loss: 282.3901; val_gene_expr_recon_loss: 784.4555; val_lambda_latent_contrastive_instanceloss: 6.3842; val_lambda_latent_contrastive_clusterloss: 2.0298; val_global_loss: 1108.3356; val_optim_loss: 1108.3356
# Epoch 38/100 |███████-------------| 38.0% val_auroc_score: 0.9082; val_auprc_score: 0.9235; val_best_acc_score: 0.8474; val_best_f1_score: 0.8364; train_kl_reg_loss: 37.8919; train_edge_recon_loss: 303.0885; train_gene_expr_recon_loss: 806.3123; train_lambda_latent_contrastive_instanceloss: 6.4556; train_lambda_latent_contrastive_clusterloss: 2.1866; train_global_loss: 1155.9349; train_optim_loss: 1155.9349; val_kl_reg_loss: 33.1951; val_edge_recon_loss: 282.6023; val_gene_expr_recon_loss: 785.8168; val_lambda_latent_contrastive_instanceloss: 6.3731; val_lambda_latent_contrastive_clusterloss: 2.0283; val_global_loss: 1110.0157; val_optim_loss: 1110.0157
# Epoch 39/100 |███████-------------| 39.0% val_auroc_score: 0.9089; val_auprc_score: 0.9255; val_best_acc_score: 0.8477; val_best_f1_score: 0.8360; train_kl_reg_loss: 37.8940; train_edge_recon_loss: 303.1372; train_gene_expr_recon_loss: 807.3341; train_lambda_latent_contrastive_instanceloss: 6.4550; train_lambda_latent_contrastive_clusterloss: 2.1890; train_global_loss: 1157.0093; train_optim_loss: 1157.0093; val_kl_reg_loss: 33.4676; val_edge_recon_loss: 282.3493; val_gene_expr_recon_loss: 779.2385; val_lambda_latent_contrastive_instanceloss: 6.3789; val_lambda_latent_contrastive_clusterloss: 2.0230; val_global_loss: 1103.4573; val_optim_loss: 1103.4573
# Epoch 40/100 |████████------------| 40.0% val_auroc_score: 0.9085; val_auprc_score: 0.9238; val_best_acc_score: 0.8471; val_best_f1_score: 0.8374; train_kl_reg_loss: 37.8954; train_edge_recon_loss: 303.1303; train_gene_expr_recon_loss: 807.7870; train_lambda_latent_contrastive_instanceloss: 6.4590; train_lambda_latent_contrastive_clusterloss: 2.1870; train_global_loss: 1157.4588; train_optim_loss: 1157.4588; val_kl_reg_loss: 33.6307; val_edge_recon_loss: 282.3929; val_gene_expr_recon_loss: 788.2561; val_lambda_latent_contrastive_instanceloss: 6.3839; val_lambda_latent_contrastive_clusterloss: 2.0426; val_global_loss: 1112.7062; val_optim_loss: 1112.7062
# Epoch 41/100 |████████------------| 41.0% val_auroc_score: 0.9088; val_auprc_score: 0.9247; val_best_acc_score: 0.8481; val_best_f1_score: 0.8377; train_kl_reg_loss: 38.0079; train_edge_recon_loss: 303.1450; train_gene_expr_recon_loss: 803.2644; train_lambda_latent_contrastive_instanceloss: 6.4555; train_lambda_latent_contrastive_clusterloss: 2.1898; train_global_loss: 1153.0627; train_optim_loss: 1153.0627; val_kl_reg_loss: 33.0656; val_edge_recon_loss: 282.2856; val_gene_expr_recon_loss: 786.5880; val_lambda_latent_contrastive_instanceloss: 6.3834; val_lambda_latent_contrastive_clusterloss: 2.0162; val_global_loss: 1110.3388; val_optim_loss: 1110.3388
# Epoch 42/100 |████████------------| 42.0% val_auroc_score: 0.9089; val_auprc_score: 0.9254; val_best_acc_score: 0.8471; val_best_f1_score: 0.8359; train_kl_reg_loss: 37.9629; train_edge_recon_loss: 303.0735; train_gene_expr_recon_loss: 805.6054; train_lambda_latent_contrastive_instanceloss: 6.4578; train_lambda_latent_contrastive_clusterloss: 2.1847; train_global_loss: 1155.2844; train_optim_loss: 1155.2844; val_kl_reg_loss: 33.0734; val_edge_recon_loss: 282.5689; val_gene_expr_recon_loss: 787.2129; val_lambda_latent_contrastive_instanceloss: 6.3771; val_lambda_latent_contrastive_clusterloss: 2.0116; val_global_loss: 1111.2439; val_optim_loss: 1111.2439
# Epoch 43/100 |████████------------| 43.0% val_auroc_score: 0.9089; val_auprc_score: 0.9249; val_best_acc_score: 0.8484; val_best_f1_score: 0.8371; train_kl_reg_loss: 37.9559; train_edge_recon_loss: 303.1604; train_gene_expr_recon_loss: 805.1173; train_lambda_latent_contrastive_instanceloss: 6.4555; train_lambda_latent_contrastive_clusterloss: 2.1831; train_global_loss: 1154.8722; train_optim_loss: 1154.8722; val_kl_reg_loss: 33.6498; val_edge_recon_loss: 282.4311; val_gene_expr_recon_loss: 783.5756; val_lambda_latent_contrastive_instanceloss: 6.3763; val_lambda_latent_contrastive_clusterloss: 2.0210; val_global_loss: 1108.0537; val_optim_loss: 1108.0537
#
# Reducing learning rate: metric has not improved more than 0.0 in the last 4 epochs.
# New learning rate is 1e-05.
#
# Epoch 44/100 |████████------------| 44.0% val_auroc_score: 0.9093; val_auprc_score: 0.9247; val_best_acc_score: 0.8481; val_best_f1_score: 0.8369; train_kl_reg_loss: 38.2163; train_edge_recon_loss: 303.0911; train_gene_expr_recon_loss: 804.4970; train_lambda_latent_contrastive_instanceloss: 6.4549; train_lambda_latent_contrastive_clusterloss: 2.1826; train_global_loss: 1154.4419; train_optim_loss: 1154.4419; val_kl_reg_loss: 33.3318; val_edge_recon_loss: 282.2042; val_gene_expr_recon_loss: 787.7436; val_lambda_latent_contrastive_instanceloss: 6.3774; val_lambda_latent_contrastive_clusterloss: 2.0126; val_global_loss: 1111.6695; val_optim_loss: 1111.6695
# Epoch 45/100 |█████████-----------| 45.0% val_auroc_score: 0.9085; val_auprc_score: 0.9241; val_best_acc_score: 0.8472; val_best_f1_score: 0.8362; train_kl_reg_loss: 38.0345; train_edge_recon_loss: 303.1160; train_gene_expr_recon_loss: 804.0880; train_lambda_latent_contrastive_instanceloss: 6.4543; train_lambda_latent_contrastive_clusterloss: 2.1831; train_global_loss: 1153.8759; train_optim_loss: 1153.8759; val_kl_reg_loss: 33.2566; val_edge_recon_loss: 282.4864; val_gene_expr_recon_loss: 787.3705; val_lambda_latent_contrastive_instanceloss: 6.3842; val_lambda_latent_contrastive_clusterloss: 2.0358; val_global_loss: 1111.5335; val_optim_loss: 1111.5335
# Epoch 46/100 |█████████-----------| 46.0% val_auroc_score: 0.9091; val_auprc_score: 0.9249; val_best_acc_score: 0.8480; val_best_f1_score: 0.8376; train_kl_reg_loss: 38.0122; train_edge_recon_loss: 303.1369; train_gene_expr_recon_loss: 805.5973; train_lambda_latent_contrastive_instanceloss: 6.4544; train_lambda_latent_contrastive_clusterloss: 2.1848; train_global_loss: 1155.3856; train_optim_loss: 1155.3856; val_kl_reg_loss: 33.3319; val_edge_recon_loss: 282.2296; val_gene_expr_recon_loss: 791.0561; val_lambda_latent_contrastive_instanceloss: 6.3799; val_lambda_latent_contrastive_clusterloss: 2.0303; val_global_loss: 1115.0276; val_optim_loss: 1115.0276
# Epoch 47/100 |█████████-----------| 47.0% val_auroc_score: 0.9082; val_auprc_score: 0.9243; val_best_acc_score: 0.8461; val_best_f1_score: 0.8359; train_kl_reg_loss: 38.0648; train_edge_recon_loss: 303.1422; train_gene_expr_recon_loss: 805.3073; train_lambda_latent_contrastive_instanceloss: 6.4516; train_lambda_latent_contrastive_clusterloss: 2.1768; train_global_loss: 1155.1428; train_optim_loss: 1155.1428; val_kl_reg_loss: 33.5280; val_edge_recon_loss: 282.6477; val_gene_expr_recon_loss: 787.3892; val_lambda_latent_contrastive_instanceloss: 6.3788; val_lambda_latent_contrastive_clusterloss: 2.0228; val_global_loss: 1111.9665; val_optim_loss: 1111.9665
#
# Stopping early: metric has not improved more than 0.0 in the last 8 epochs.
# If the early stopping criterion is too strong, please instantiate it with different parameters in the train method.
# Model training finished after 22 min 25 sec.
# Using best model state, which was in epoch 39.
#
# --- MODEL EVALUATION ---
# val AUROC score: 0.9087
# val AUPRC score: 0.9245
# val best accuracy score: 0.8470
# val best F1 score: 0.8360
# val MSE score: 2.6185

# %%
# Compute latent neighbor graph
latent_key = 'garfield_latent'
sc.pp.neighbors(model.adata,
                use_rep=latent_key,
                key_added=latent_key)
# Compute UMAP embedding
sc.tl.umap(model.adata,
           neighbors_key=latent_key)

# %%
# Compute latent Leiden clustering
latent_leiden_resolution = 1.2
latent_cluster_key = f"latent_leiden_{str(latent_leiden_resolution)}"
latent_key = "garfield_latent"

sc.tl.leiden(adata=model.adata,
             resolution=latent_leiden_resolution,
             key_added=latent_cluster_key,
             neighbors_key=latent_key)
len(model.adata.obs[latent_cluster_key].unique())
# Out:
# 24

# %% [markdown]
# ### Visualize Garfield Latent Space

# %%
sc.pl.umap(model.adata, color=['celltype_mapped_refined', latent_cluster_key], show=True, wspace=0.35, size=3)

# %%
## celltype
sc.pl.umap(model.adata, color=[ 'celltype_mapped_refined'], ncols=3,
           wspace=0.5, show=True, legend_loc='on data', size=3)

# %%
## batch information
sc.pl.umap(model.adata, color=['batch'], show=True)

# %%
## sample information
sc.pl.umap(model.adata, color=['sample'], ncols=3,
           wspace=0.5, show=True)

# %%
### Display spatial location distribution by sample
import squidpy as sq

batch_indeces = list(model.adata.obs['sample'].unique())
for batch_idx in batch_indeces:
    tmp = model.adata[model.adata.obs['sample'] == batch_idx, ]

    # Visualize cell-level annotated data in physical space
    sq.pl.spatial_scatter(tmp, color=cell_type_key, shape=None, figsize=(12, 12))
    sq.pl.spatial_scatter(tmp, color=latent_cluster_key, shape=None, figsize=(12, 12))
# Out:
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`
# WARNING: Please specify a valid `library_id` or set it permanently in `adata.uns['spatial']`

# %%
# Save trained model
model_folder_path = f"{workdir}/model"
os.makedirs(model_folder_path, exist_ok=True)

model.save(dir_path=model_folder_path,
           overwrite=True,
           save_adata=True,
           adata_file_name="adata_ref.h5ad")
# Out:
# Model saved successfully using pickle at /home/zhouweige/zhouwg_data/project/Garfield_tutorials/result/garfield_spRNA_embryo/model/attr.pkl
